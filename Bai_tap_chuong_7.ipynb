# %% [markdown]
# <a href="https://colab.research.google.com/github/gnasche-2003/thuchanhtoancp/blob/main/Bai_tap_chuong_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #![chuong7-bai1.png](data:image/png;base64,...)

# %% [markdown]
# + bai 1b

# %%
from sympy import Symbol, solve, Integral, Derivative

# %%
x = Symbol('x')
f = (1/3)*(x*x + 2)**3
a = Symbol('a')

# %%
Ketqua = Integral(f**1/2, (x, 0, a)).doit()
Ketqua

# %% [markdown]
# + bai 1c

# %% [markdown]
# # ![chuong 7 - bai 2.png](data:image/png;base64,...)

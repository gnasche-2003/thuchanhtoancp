# %% [markdown]
# <a href="https://colab.research.google.com/github/gnasche-2003/thuchanhtoancp/blob/main/Bai_tap_chuong_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![s.png](data:image/png;base64,...)

# %% [markdown]
# # ![Screenshot 2022-03-16 163840.png](data:image/png;base64,...)

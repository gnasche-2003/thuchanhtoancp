# %% [markdown]
# <a href="https://colab.research.google.com/github/gnasche-2003/thuchanhtoancp/blob/main/Bai_tap_chuong_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
# 1.1 
def bai1_1(n):
  if n == 1:
    return 4
  else:
    return 1/2*(an + 8)

# %% [markdown]
# # ![image.png](data:image/png;base64,...)
